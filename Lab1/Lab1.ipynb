# %%
import matplotlib.pyplot as plt
import pandas as pd
low_memory = False
file_data = pd.read_csv('Most-Recent-Cohorts-Scorecard-Elements.csv')
file_data.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR                    INSTURL  \
# 0     AL              www.aamu.edu/
# 1     AL                www.uab.edu
# 2     AL  www.amridgeuniversity.edu
# 3     AL                www.uah.edu
# 4     AL              www.alasu.edu
#
#                                               NPCURL  HCM2  PREDDEG  ...  \
# 0      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3  ...
# 1           uab.studentaidcalculator.com/survey.aspx     0        3  ...
# 2                   www2.amridgeuniversity.edu:9091/     0        3  ...
# 3                                    finaid.uah.edu/     0        3  ...
# 4  www.alasu.edu/cost-aid/forms/calculator/index....     0        3  ...
#
#    RET_PTL4_POOLED_SUPP  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GT_25K_P6  \
# 0                   NaN    0.8159   0.0877            29900      0.453
# 1                   NaN    0.5218   0.2363            40200      0.669
# 2                   NaN    0.8781   0.8571            40100      0.658
# 3                   NaN    0.4589   0.2255            45600      0.685
# 4                   NaN    0.7692   0.0974            26700      0.393
#
#    GRAD_DEBT_MDN_SUPP  GRAD_DEBT_MDN10YR_SUPP  RPY_3YR_RT_SUPP  \
# 0               35000        361.891446885773     0.2458495231
# 1               21500        222.304745944118     0.5199110572
# 2               23000        237.814379382079     0.2331002331
# 3               23500        242.984257194733     0.5490029699
# 4               32091        331.813097771753     0.1963538553
#
#    C150_L4_POOLED_SUPP  C150_4_POOLED_SUPP
# 0                  NaN              0.3303
# 1                  NaN              0.5504
# 2                  NaN   PrivacySuppressed
# 3                  NaN              0.4776
# 4                  NaN              0.2663
#
# [5 rows x 123 columns]

# %%
file = file_data.groupby(['STABBR']).size()
file.head()
# Out:
# STABBR
# AK      9
# AL     96
# AR     92
# AS      1
# AZ    133
# dtype: int64

# %%
ax = file.plot(kind= 'bar', title="No of Schools Per State", figsize= (10, 8), legend= False, fontsize= 8, sort_columns= True, color= 'b')
ax.set_xlabel("State", fontsize= 8)
ax.set_ylabel("No of Schools", fontsize= 8)
plt.show()
